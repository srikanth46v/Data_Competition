# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import json
import sys

directory = "C:/Users/Srikanth/Downloads/Data_version1/data"
user_data = directory + "/train"
valid_data = directory + "/val"
test_data = directory + "/test" # this can be the label book, or any other test set you create

### DO NOT MODIFY BELOW THIS LINE, THIS IS THE FIXED MODEL ###
batch_size = 8
tf.random.set_seed(123)


if __name__ == "__main__":
    train = tf.keras.preprocessing.image_dataset_from_directory(
        user_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=True,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )

    valid = tf.keras.preprocessing.image_dataset_from_directory(
        valid_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=True,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )

    total_length = ((train.cardinality() + valid.cardinality()) * batch_size).numpy()
    if total_length > 10_000:
        print(f"Dataset size larger than 10,000. Got {total_length} examples")
        sys.exit()

    test = tf.keras.preprocessing.image_dataset_from_directory(
        test_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=False,
        image_size=(32, 32))


    base_model = tf.keras.applications.ResNet50(
        input_shape=(32, 32, 3),
        include_top=False,
        weights=None,
    )
    base_model = tf.keras.Model(
        base_model.inputs, outputs=[base_model.get_layer("conv2_block3_out").output]
    )

    inputs = tf.keras.Input(shape=(32, 32, 3))
    x = tf.keras.applications.resnet.preprocess_input(inputs)
    x = base_model(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(10)(x)
    model = tf.keras.Model(inputs, x)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    model.summary()
    loss_0, acc_0 = model.evaluate(valid)
    print(f"loss {loss_0}, acc {acc_0}")

    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        "best_model",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        train,
        validation_data=valid,
        epochs=100,
        callbacks=[checkpoint],
    )

    model.load_weights("best_model")

    loss, acc = model.evaluate(valid)
    print(f"final loss {loss}, final acc {acc}")

    test_loss, test_acc = model.evaluate(test)
    print(f"test loss {test_loss}, test acc {test_acc}")
# Out:
# Found 1826 files belonging to 10 classes.
# Found 800 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.
# c:\users\srikanth\anaconda3\envs\scrapping\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# tf.__operators__.getitem (Sl (None, 32, 32, 3)         0
# _________________________________________________________________
# tf.nn.bias_add (TFOpLambda)  (None, 32, 32, 3)         0
# _________________________________________________________________
# model (Functional)           (None, 8, 8, 256)         229760
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# =================================================================
# Total params: 232,330
# Trainable params: 229,386
# Non-trainable params: 2,944
# _________________________________________________________________
# 100/100 [==============================] - 4s 22ms/step - loss: 33.5993 - accuracy: 0.0975
# loss 33.59934997558594, acc 0.09749999642372131
# Epoch 1/100
# 229/229 [==============================] - 17s 60ms/step - loss: 2.0005 - accuracy: 0.3094 - val_loss: 2.0075 - val_accuracy: 0.1912
# Epoch 2/100
# 229/229 [==============================] - 13s 58ms/step - loss: 1.4066 - accuracy: 0.5570 - val_loss: 1.6096 - val_accuracy: 0.4200
# Epoch 3/100
# 229/229 [==============================] - 13s 59ms/step - loss: 1.1032 - accuracy: 0.6605 - val_loss: 1.6233 - val_accuracy: 0.4462
# Epoch 4/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.9341 - accuracy: 0.7125 - val_loss: 1.3031 - val_accuracy: 0.5462
# Epoch 5/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.7523 - accuracy: 0.7853 - val_loss: 1.2636 - val_accuracy: 0.5275
# Epoch 6/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.6509 - accuracy: 0.8111 - val_loss: 1.0228 - val_accuracy: 0.6525
# Epoch 7/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.5513 - accuracy: 0.8417 - val_loss: 0.9454 - val_accuracy: 0.6762
# Epoch 8/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.4591 - accuracy: 0.8675 - val_loss: 0.9516 - val_accuracy: 0.6612
# Epoch 9/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0
100
# 229/229 [==============================] - 13s 55ms/step - loss: 0.0502 - accuracy: 0.9863 - val_loss: 1.4294 - val_accuracy: 0.6325
# Epoch 41/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0352 - accuracy: 0.9929 - val_loss: 1.0957 - val_accuracy: 0.6812
# Epoch 42/100
# 229/229 [==============================] - 13s 55ms/step - loss: 0.0249 - accuracy: 0.9962 - val_loss: 1.1145 - val_accuracy: 0.7063
# Epoch 43/100
# 229/229 [==============================] - 13s 55ms/step - loss: 0.0302 - accuracy: 0.9956 - val_loss: 1.2199 - val_accuracy: 0.6900
# Epoch 44/100
# 229/229 [==============================] - 13s 55ms/step - loss: 0.0453 - accuracy: 0.9880 - val_loss: 1.4190 - val_accuracy: 0.6112
# Epoch 45/100
# 229/229 [==============================] - 13s 55ms/step - loss: 0.0412 - accuracy: 0.9923 - val_loss: 1.3905 - val_accuracy: 0.6388
# Epoch 46/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0360 - accuracy: 0.9901 - val_loss: 1.6330 - val_accuracy: 0.6062
# Epoch 47/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0396 - accuracy: 0.9912 - val_loss: 2.5735 - val_accuracy: 0.5250
# Epoch 48/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0492 - accuracy: 0.9874 - val_loss: 1.4595 - val_accuracy: 0.6513
# Epoch 49/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0378 - accuracy: 0.9929 - val_loss: 1.1987 - val_accuracy: 0.6900
# Epoch 50/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0502 - accuracy: 0.9874 - val_loss: 1.4051 - val_accuracy: 0.6450
# Epoch 51/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0269 - accuracy: 0.9945 - val_loss: 1.3851 - val_accuracy: 0.6662
# Epoch 52/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0173 - accuracy: 0.9978 - val_loss: 0.9677 - val_accuracy: 0.7275
# Epoch 53/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0289 - accuracy: 0.9929 - val_loss: 1.9017 - val_accuracy: 0.5838
# Epoch 54/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 1.4438 - val_accuracy: 0.6538
# Epoch 55/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0367 - accuracy: 0.9918 - val_loss: 1.1464 - val_accuracy: 0.6725
# Epoch 56/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0215 - accuracy: 0.9967 - val_loss: 1.2632 - val_accuracy: 0.6925
# Epoch 57/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0194 - accuracy: 0.9978 - val_loss: 1.8124 - val_accuracy: 0.6300
# Epoch 58/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0135 - accuracy: 0.9984 - val_loss: 2.9745 - val_accuracy: 0.5225
# Epoch 59/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0215 - accuracy: 0.9951 - val_loss: 1.4910 - val_accuracy: 0.6488
# Epoch 60/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0304 - accuracy: 0.9912 - val_loss: 1.3470 - val_accuracy: 0.6612
# Epoch 61/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0396 - accuracy: 0.9890 - val_loss: 1.5625 - val_accuracy: 0.6463
# Epoch 62/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0394 - accuracy: 0.9912 - val_loss: 1.1777 - val_accuracy: 0.7063
# Epoch 63/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0540 - accuracy: 0.9814 - val_loss: 1.4156 - val_accuracy: 0.6787
# Epoch 64/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0375 - accuracy: 0.9918 - val_loss: 1.5278 - val_accuracy: 0.6687
# Epoch 65/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0196 - accuracy: 0.9967 - val_loss: 1.0707 - val_accuracy: 0.6963
# Epoch 66/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0227 - accuracy: 0.9951 - val_loss: 1.1034 - val_accuracy: 0.7075
# Epoch 67/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0178 - accuracy: 0.9962 - val_loss: 1.0551 - val_accuracy: 0.7038
# Epoch 68/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0143 - accuracy: 0.9984 - val_loss: 1.2277 - val_accuracy: 0.6725
# Epoch 69/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0099 - accuracy: 0.9995 - val_loss: 0.9297 - val_accuracy: 0.7375
# Epoch 70/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0131 - accuracy: 0.9973 - val_loss: 0.9239 - val_accuracy: 0.7400
# Epoch 71/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 1.2482 - val_accuracy: 0.6938
# Epoch 72/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0497 - accuracy: 0.9863 - val_loss: 2.2525 - val_accuracy: 0.5850
# Epoch 73/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0523 - accuracy: 0.9819 - val_loss: 1.3176 - val_accuracy: 0.6388
# Epoch 74/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0236 - accuracy: 0.9956 - val_loss: 1.4437 - val_accuracy: 0.6712
# Epoch 75/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0210 - accuracy: 0.9945 - val_loss: 1.7888 - val_accuracy: 0.5875
# Epoch 76/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0161 - accuracy: 0.9989 - val_loss: 1.2995 - val_accuracy: 0.6837
# Epoch 77/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.0404 - val_accuracy: 0.7075
# Epoch 78/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 1.2713 - val_accuracy: 0.6787
# Epoch 79/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0211 - accuracy: 0.9951 - val_loss: 1.0828 - val_accuracy: 0.7100
# Epoch 80/100
# 229/229 [==============================] - 13s 59ms/step - loss: 0.0108 - accuracy: 0.9984 - val_loss: 1.4881 - val_accuracy: 0.6550
# Epoch 81/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0124 - accuracy: 0.9984 - val_loss: 0.9600 - val_accuracy: 0.7287
# Epoch 82/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0364 - accuracy: 0.9907 - val_loss: 1.9698 - val_accuracy: 0.5838
# Epoch 83/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0358 - accuracy: 0.9863 - val_loss: 1.2070 - val_accuracy: 0.6950
# Epoch 84/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0191 - accuracy: 0.9951 - val_loss: 1.3405 - val_accuracy: 0.6750
# Epoch 85/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0122 - accuracy: 0.9978 - val_loss: 1.4514 - val_accuracy: 0.6725
# Epoch 86/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0174 - accuracy: 0.9956 - val_loss: 1.0914 - val_accuracy: 0.7350
# Epoch 87/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0281 - accuracy: 0.9923 - val_loss: 1.2516 - val_accuracy: 0.7013
# Epoch 88/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0235 - accuracy: 0.9940 - val_loss: 1.3256 - val_accuracy: 0.6837
# Epoch 89/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0301 - accuracy: 0.9907 - val_loss: 1.0844 - val_accuracy: 0.7212
# Epoch 90/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0199 - accuracy: 0.9956 - val_loss: 1.0932 - val_accuracy: 0.7088
# Epoch 91/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0104 - accuracy: 0.9984 - val_loss: 0.8669 - val_accuracy: 0.7538
# Epoch 92/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0224 - accuracy: 0.9956 - val_loss: 1.6591 - val_accuracy: 0.6562
# Epoch 93/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0265 - accuracy: 0.9923 - val_loss: 1.6654 - val_accuracy: 0.6500
# Epoch 94/100
# 229/229 [==============================] - 13s 58ms/step - loss: 0.0136 - accuracy: 0.9989 - val_loss: 1.1083 - val_accuracy: 0.7013
# Epoch 95/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.7325
# Epoch 96/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0099 - accuracy: 0.9978 - val_loss: 1.1605 - val_accuracy: 0.7175
# Epoch 97/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0172 - accuracy: 0.9962 - val_loss: 1.2216 - val_accuracy: 0.7013
# Epoch 98/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.0479 - val_accuracy: 0.7337
# Epoch 99/100
# 229/229 [==============================] - 13s 57ms/step - loss: 0.0229 - accuracy: 0.9929 - val_loss: 1.3021 - val_accuracy: 0.6762
# Epoch 100/100
# 229/229 [==============================] - 13s 56ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9737 - val_accuracy: 0.7600
# 100/100 [==============================] - 2s 20ms/step - loss: 0.9737 - accuracy: 0.7600
# final loss 0.9737246632575989, final acc 0.7599999904632568
# 2/2 [==============================] - 0s 73ms/step - loss: 1.7519 - accuracy: 0.6538
# test loss 1.7518702745437622, test acc 0.6538461446762085

# %%
# plot the loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
