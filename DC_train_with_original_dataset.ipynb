# %% [markdown]
# # Training the model with code and dataset optained from competition

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import json
import sys

directory = "C:/Users/Srikanth/Downloads/data/data"
user_data = directory + "/train"
valid_data = directory + "/val"
test_data = directory + "/test" # this can be the label book, or any other test set you create

### DO NOT MODIFY BELOW THIS LINE, THIS IS THE FIXED MODEL ###
batch_size = 8
tf.random.set_seed(123)


if __name__ == "__main__":
    train = tf.keras.preprocessing.image_dataset_from_directory(
        user_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=True,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )

    valid = tf.keras.preprocessing.image_dataset_from_directory(
        valid_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=True,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )

    total_length = ((train.cardinality() + valid.cardinality()) * batch_size).numpy()
    if total_length > 10_000:
        print(f"Dataset size larger than 10,000. Got {total_length} examples")
        sys.exit()

    test = tf.keras.preprocessing.image_dataset_from_directory(
        test_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=False,
        image_size=(32, 32))



    base_model = tf.keras.applications.ResNet50(
        input_shape=(32, 32, 3),
        include_top=False,
        weights=None,
    )
    base_model = tf.keras.Model(
        base_model.inputs, outputs=[base_model.get_layer("conv2_block3_out").output]
    )

    inputs = tf.keras.Input(shape=(32, 32, 3))
    x = tf.keras.applications.resnet.preprocess_input(inputs)
    x = base_model(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(10)(x)
    model = tf.keras.Model(inputs, x)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    model.summary()
    loss_0, acc_0 = model.evaluate(valid)
    print(f"loss {loss_0}, acc {acc_0}")

    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        "best_model",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        train,
        validation_data=valid,
        epochs=100,
        callbacks=[checkpoint],
    )

    model.load_weights("best_model")

    loss, acc = model.evaluate(valid)
    print(f"final loss {loss}, final acc {acc}")

    test_loss, test_acc = model.evaluate(test)
    print(f"test loss {test_loss}, test acc {test_acc}")
# Out:
# Found 2067 files belonging to 10 classes.
# Found 813 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.
# c:\users\srikanth\anaconda3\envs\scrapping\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# tf.__operators__.getitem (Sl (None, 32, 32, 3)         0
# _________________________________________________________________
# tf.nn.bias_add (TFOpLambda)  (None, 32, 32, 3)         0
# _________________________________________________________________
# model (Functional)           (None, 8, 8, 256)         229760
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# =================================================================
# Total params: 232,330
# Trainable params: 229,386
# Non-trainable params: 2,944
# _________________________________________________________________
# 102/102 [==============================] - 1s 8ms/step - loss: 33.4250 - accuracy: 0.0996
# loss 33.425010681152344, acc 0.09963099658489227
# Epoch 1/100
# 259/259 [==============================] - 8s 27ms/step - loss: 2.0174 - accuracy: 0.2922 - val_loss: 1.9974 - val_accuracy: 0.2226
# Epoch 2/100
# 259/259 [==============================] - 7s 27ms/step - loss: 1.4718 - accuracy: 0.5225 - val_loss: 1.5886 - val_accuracy: 0.4121
# Epoch 3/100
# 259/259 [==============================] - 8s 30ms/step - loss: 1.2250 - accuracy: 0.6125 - val_loss: 1.3521 - val_accuracy: 0.5203
# Epoch 4/100
# 259/259 [==============================] - 7s 29ms/step - loss: 1.0237 - accuracy: 0.6701 - val_loss: 1.1948 - val_accuracy: 0.5720
# Epoch 5/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.8896 - accuracy: 0.7247 - val_loss: 1.0371 - val_accuracy: 0.6445
# Epoch 6/100
# 259/259 [==============================] - 7s 26ms/step - loss: 0.7972 - accuracy: 0.7475 - val_loss: 0.9704 - val_accuracy: 0.6704
# Epoch 7/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.7135 - accuracy: 0.7765 - val_loss: 1.1397 - val_accuracy: 0.6027
# Epoch 8/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.5874 - accuracy: 0.8331 - val_loss: 1.2846 - val_accuracy: 0.5486
# Epoch 9/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.5259 - accuracy: 0.8447 - val_loss: 1.1617 - val_accuracy: 0.5916
# Epoch 10/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.4704 - accuracy: 0.8655 - val_loss: 1.1466 - val_accuracy: 0.5904
# Epoch 11/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.3963 - accuracy: 0.8892 - val_loss: 1.3913 - val_accuracy: 0.5461
# Epoch 12/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.3552 - accuracy: 0.9090 - val_loss: 1.6303 - val_accuracy: 0.5068
# Epoch 13/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.2844 - accuracy: 0.9328 - val_loss: 1.3617 - val_accuracy: 0.5633
# Epoch 14/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.2685 - accuracy: 0.9371 - val_loss: 1.1824 - val_accuracy: 0.6162
# Epoch 15/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.2135 - accuracy: 0.9584 - val_loss: 1.2776 - val_accuracy: 0.5879
# Epoch 16/100
# 259/259 [==============================] - 7s 26ms/step - loss: 0.2141 - accuracy: 0.9492 - val_loss: 1.4891 - val_accuracy: 0.5658
# Epoch 17/100
# 259/259 [==============================] - 7s 26ms/step - loss: 0.1711 - accuracy: 0.9686 - val_loss: 1.4233 - val_accuracy: 0.5670
# Epoch 18/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.1646 - accuracy: 0.9642 - val_loss: 1.2541 - val_accuracy: 0.5830
# Epoch 19/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.1419 - accuracy: 0.9715 - val_loss: 1.1436 - val_accuracy: 0.6507
# Epoch 20/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.1397 - accuracy: 0.9719 - val_loss: 1.7193 - val_accuracy: 0.5240
# Epoch 21/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.1342 - accuracy: 0.9724 - val_loss: 1.3958 - val_accuracy: 0.5990
# Epoch 22/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.1026 - accuracy: 0.9802 - val_loss: 1.3775 - val_accuracy: 0.6310
# Epoch 23/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.1072 - accuracy: 0.9758 - val_loss: 1.2853 - val_accuracy: 0.6052
# Epoch 24/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.1044 - accuracy: 0.9777 - val_loss: 1.3500 - val_accuracy: 0.6113
# Epoch 25/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0850 - accuracy: 0.9874 - val_loss: 1.4808 - val_accuracy: 0.5560
# Epoch 26/100
# 259/259 [==============================] - 8s 33ms/step - loss: 0.1071 - accuracy: 0.9734 - val_loss: 1.6135 - val_accuracy: 0.5646
# Epoch 27/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0804 - accuracy: 0.9860 - val_loss: 1.4098 - val_accuracy: 0.6335
# Epoch 28/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0856 - accuracy: 0.9802 - val_loss: 1.3138 - val_accuracy: 0.6199
# Epoch 29/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0758 - accuracy: 0.9845 - val_loss: 2.8413 - val_accuracy: 0.4453
# Epoch 30/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0922 - accuracy: 0.9787 - val_loss: 1.6548 - val_accuracy: 0.5867
# Epoch 31/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0821 - accuracy: 0.9821 - val_loss: 1.6778 - val_accuracy: 0.5769
# Epoch 32/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0570 - accuracy: 0.9884 - val_loss: 2.2930 - val_accuracy: 0.5055
# Epoch 33/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0469 - accuracy: 0.9927 - val_loss: 1.4604 - val_accuracy: 0.6248
# Epoch 34/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0433 - accuracy: 0.9932 - val_loss: 1.4531 - val_accuracy: 0.6285
# Epoch 35/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.0508 - accuracy: 0.9884 - val_loss: 1.3549 - val_accuracy: 0.6285
# Epoch 36/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0894 - accuracy: 0.9797 - val_loss: 2.4723 - val_accuracy: 0.5535
# Epoch 37/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0494 - accuracy: 0.9903 - val_loss: 1.3452 - val_accuracy: 0.6470
# Epoch 38/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0432 - accuracy: 0.9918 - val_loss: 1.4747 - val_accuracy: 0.6039
# Epoch 39/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0520 - accuracy: 0.9884 - val_loss: 1.7765 - val_accuracy: 0.5830
# Epoch 40/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0527 - accuracy: 0.9860 - val_loss: 2.6077 - val_accuracy: 0.5055
# Epoch 41/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0544 - accuracy: 0.9884 - val_loss: 1.6811 - val_accuracy: 0.5941
# Epoch 42/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0586 - accuracy: 0.9889 - val_loss: 2.2826 - val_accuracy: 0.5166
# Epoch 43/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0424 - accuracy: 0.9932 - val_loss: 1.4945 - val_accuracy: 0.6162
# Epoch 44/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0308 - accuracy: 0.9956 - val_loss: 1.4384 - val_accuracy: 0.6322
# Epoch 45/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0537 - accuracy: 0.9865 - val_loss: 1.6955 - val_accuracy: 0.5929
# Epoch 46/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0480 - accuracy: 0.9874 - val_loss: 1.4616 - val_accuracy: 0.6101
# Epoch 47/100
# 259/259 [==============================] - 7s 26ms/step - loss: 0.0440 - accuracy: 0.9923 - val_loss: 1.9842 - val_accuracy: 0.5424
# Epoch 48/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0624 - accuracy: 0.9845 - val_loss: 1.4666 - val_accuracy: 0.6064
# Epoch 49/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0446 - accuracy: 0.9903 - val_loss: 1.8954 - val_accuracy: 0.5584
# Epoch 50/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0408 - accuracy: 0.9918 - val_loss: 1.3990 - val_accuracy: 0.6359
# Epoch 51/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0525 - accuracy: 0.9865 - val_loss: 1.9309 - val_accuracy: 0.5879
# Epoch 52/100
# 259/259 [==============================] - 7s 26ms/step - loss: 0.0380 - accuracy: 0.9918 - val_loss: 1.7316 - val_accuracy: 0.6371
# Epoch 53/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0398 - accuracy: 0.9918 - val_loss: 1.5877 - val_accuracy: 0.6162
# Epoch 54/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0433 - accuracy: 0.9879 - val_loss: 1.3765 - val_accuracy: 0.6101
# Epoch 55/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0521 - accuracy: 0.9869 - val_loss: 1.4803 - val_accuracy: 0.6224
# Epoch 56/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0278 - accuracy: 0.9956 - val_loss: 1.1867 - val_accuracy: 0.6827
# Epoch 57/100
# 259/259 [==============================] - 8s 31ms/step - loss: 0.0329 - accuracy: 0.9923 - val_loss: 1.8633 - val_accuracy: 0.5892
# Epoch 58/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.0302 - accuracy: 0.9947 - val_loss: 2.2338 - val_accuracy: 0.5621
# Epoch 59/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.0231 - accuracy: 0.9961 - val_loss: 1.3949 - val_accuracy: 0.6408
# Epoch 60/100
# 259/259 [==============================] - 8s 31ms/step - loss: 0.0210 - accuracy: 0.9971 - val_loss: 1.4112 - val_accuracy: 0.6347
# Epoch 61/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0294 - accuracy: 0.9937 - val_loss: 1.6755 - val_accuracy: 0.6015
# Epoch 62/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0424 - accuracy: 0.9869 - val_loss: 3.1555 - val_accuracy: 0.4871
# Epoch 63/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0341 - accuracy: 0.9918 - val_loss: 1.9994 - val_accuracy: 0.5781
# Epoch 64/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0366 - accuracy: 0.9898 - val_loss: 1.7997 - val_accuracy: 0.6002
# Epoch 65/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0240 - accuracy: 0.9961 - val_loss: 1.5294 - val_accuracy: 0.6113
# Epoch 66/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0265 - accuracy: 0.9947 - val_loss: 2.0431 - val_accuracy: 0.5633
# Epoch 67/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0480 - accuracy: 0.9860 - val_loss: 2.4067 - val_accuracy: 0.5351
# Epoch 68/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0421 - accuracy: 0.9908 - val_loss: 2.2655 - val_accuracy: 0.5461
# Epoch 69/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0215 - accuracy: 0.9947 - val_loss: 1.7376 - val_accuracy: 0.6101
# Epoch 70/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0202 - accuracy: 0.9971 - val_loss: 2.0235 - val_accuracy: 0.5756
# Epoch 71/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0382 - accuracy: 0.9889 - val_loss: 1.8435 - val_accuracy: 0.6002
# Epoch 72/100
# 259/259 [==============================] - 8s 31ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 3.4726 - val_accuracy: 0.4084
# Epoch 73/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0267 - accuracy: 0.9937 - val_loss: 1.6226 - val_accuracy: 0.6199
# Epoch 74/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0546 - accuracy: 0.9869 - val_loss: 1.5373 - val_accuracy: 0.6175
# Epoch 75/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0326 - accuracy: 0.9903 - val_loss: 2.5064 - val_accuracy: 0.5043
# Epoch 76/100
# 259/259 [==============================] - 8s 31ms/step - loss: 0.0350 - accuracy: 0.9942 - val_loss: 1.4716 - val_accuracy: 0.6408
# Epoch 77/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0226 - accuracy: 0.9937 - val_loss: 1.4133 - val_accuracy: 0.6421
# Epoch 78/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0356 - accuracy: 0.9913 - val_loss: 1.7356 - val_accuracy: 0.6150
# Epoch 79/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0195 - accuracy: 0.9966 - val_loss: 1.3530 - val_accuracy: 0.6679
# Epoch 80/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0207 - accuracy: 0.9952 - val_loss: 1.8348 - val_accuracy: 0.6089
# Epoch 81/100
# 259/259 [==============================] - 8s 31ms/step - loss: 0.0206 - accuracy: 0.9952 - val_loss: 1.6313 - val_accuracy: 0.6421
# Epoch 82/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0195 - accuracy: 0.9966 - val_loss: 1.4632 - val_accuracy: 0.6445
# Epoch 83/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0099 - accuracy: 0.9995 - val_loss: 1.4160 - val_accuracy: 0.6593
# Epoch 84/100
# 259/259 [==============================] - 8s 31ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 1.6973 - val_accuracy: 0.6322
# Epoch 85/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0095 - accuracy: 0.9995 - val_loss: 1.8793 - val_accuracy: 0.5953
# Epoch 86/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0422 - accuracy: 0.9879 - val_loss: 2.1795 - val_accuracy: 0.5756
# Epoch 87/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0803 - accuracy: 0.9758 - val_loss: 3.0586 - val_accuracy: 0.4957
# Epoch 88/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0319 - accuracy: 0.9908 - val_loss: 1.4050 - val_accuracy: 0.6617
# Epoch 89/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0192 - accuracy: 0.9956 - val_loss: 1.4774 - val_accuracy: 0.6482
# Epoch 90/100
# 259/259 [==============================] - 8s 32ms/step - loss: 0.0209 - accuracy: 0.9952 - val_loss: 1.9349 - val_accuracy: 0.5707
# Epoch 91/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0191 - accuracy: 0.9961 - val_loss: 2.0338 - val_accuracy: 0.6101
# Epoch 92/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0183 - accuracy: 0.9966 - val_loss: 1.7525 - val_accuracy: 0.6138
# Epoch 93/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0116 - accuracy: 0.9981 - val_loss: 1.6561 - val_accuracy: 0.6187
# Epoch 94/100
# 259/259 [==============================] - 8s 30ms/step - loss: 0.0225 - accuracy: 0.9952 - val_loss: 1.6949 - val_accuracy: 0.6150
# Epoch 95/100
# 259/259 [==============================] - 7s 29ms/step - loss: 0.0251 - accuracy: 0.9947 - val_loss: 1.9254 - val_accuracy: 0.5843
# Epoch 96/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0369 - accuracy: 0.9894 - val_loss: 2.2803 - val_accuracy: 0.5424
# Epoch 97/100
# 259/259 [==============================] - 7s 28ms/step - loss: 0.0227 - accuracy: 0.9942 - val_loss: 2.0237 - val_accuracy: 0.5929
# Epoch 98/100
# 259/259 [==============================] - 8s 29ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 1.5111 - val_accuracy: 0.6667
# Epoch 99/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0191 - accuracy: 0.9952 - val_loss: 1.6121 - val_accuracy: 0.6470
# Epoch 100/100
# 259/259 [==============================] - 7s 27ms/step - loss: 0.0373 - accuracy: 0.9913 - val_loss: 2.0739 - val_accuracy: 0.5830
# 102/102 [==============================] - 1s 8ms/step - loss: 1.1867 - accuracy: 0.6827
# final loss 1.1866662502288818, final acc 0.6826568245887756
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8869 - accuracy: 0.5577
# test loss 1.8868510723114014, test acc 0.557692289352417

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
